# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

data = pd.read_csv("C:/Users/debad/Downloads/Unemployment_Rate_upto_11_2020.csv")
data.columns = ["States", "Date", "Frequency",
                "Estimated Unemployment Rate", "Estimated Employed",
                "Estimated Labour Participation Rate", "Region",
                "longitude", "latitude"]

plt.figure(figsize=(12, 10))
plt.title("Indian Unemployment - Estimated Employed")
sns.histplot(x="Estimated Employed", hue="Region", data=data)
plt.show()
plt.figure(figsize=(12, 10))
plt.title("Indian Unemployment - Estimated Unemployment Rate")
sns.histplot(x="Estimated Unemployment Rate", hue="Region", data=data)
plt.show()
unemployment = data[["States", "Region", "Estimated Unemployment Rate"]]
figure = px.sunburst(unemployment, path=["Region", "States"],
                     values="Estimated Unemployment Rate",
                     width=700, height=700, color_continuous_scale="RdYlGn",
                     title="Unemployment Rate in India")
figure.show()
numeric_data = data.select_dtypes(include='number')
correlation_matrix = numeric_data.corr()
# Out:
# <div>                            <div id="9bef7f8c-6b0d-4769-b638-397ad49def19" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bef7f8c-6b0d-4769-b638-397ad49def19")) {                    Plotly.newPlot(                        "9bef7f8c-6b0d-4769-b638-397ad49def19",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Estimated Unemployment Rate=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["South/Andhra Pradesh","Northeast/Assam","East/Bihar","West/Chhattisgarh","North/Delhi","West/Goa","West/Gujarat","North/Haryana","North/Himachal Pradesh","North/Jammu & Kashmir","East/Jharkhand","South/Karnataka","South/Kerala","West/Madhya Pradesh","West/Maharashtra","Nort
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

try:
    sns.set_theme(style='whitegrid')
    numeric_data = data.select_dtypes(include='number')
    plt.figure(figsize=(12, 10))
    sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
    plt.show()

except Exception as e:
    print(f"An error occurred: {e}")
